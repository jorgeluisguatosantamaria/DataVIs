# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
data = {'Industrial':  [25],
        'Residencial': [37],
        'Comercial': [19],
        'A. Público': [7],
        'Otros': [12],
        }

df = pd.DataFrame (data, columns = ['Industrial','Residencial','Comercial','A. Público', 'Otros' ])
df.to_csv('Participación.csv', sep=',')
# Out:
#    Industrial  Residencial  Comercial  A. Público  Otros
# 0          25           37         19           7     12

# %%
df = pd.read_excel('PROD-DEM 2016-2021_2.xlsx',
                       sheet_name='POTENCIA-30M',
                       skiprows=range(5),
                       #skipfooter=2,
                       #parse_dates = ['Fecha'],
                       )
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92400 entries, 0 to 92399
# Data columns (total 6 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Fecha                                                    92400 non-null  datetime64[ns]
#  1   Día                                                      92400 non-null  object
#  2   Hora                                                     92400 non-null  object
#  3   FechaHora                                                92400 non-null  datetime64[ns]
#  4   PRODUCCIÓN
# (Incluye las importaciones)                 92400 non-null  float64
#  5   DEMANDA NACIONAL
# (Incluye las pérdidas en transmisión)  92400 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(2)
# memory usage: 4.2+ MB

# %%
df.head(5)
# Out:
#        Fecha  ... DEMANDA NACIONAL \n(Incluye las pérdidas en transmisión)
# 0 2016-01-01  ...                                            2396.90
# 1 2016-01-01  ...                                            2396.13
# 2 2016-01-01  ...                                            2358.84
# 3 2016-01-01  ...                                            2307.70
# 4 2016-01-01  ...                                            2231.39
#
# [5 rows x 6 columns]

# %%
df.tail(5)
# Out:
#            Fecha  ... DEMANDA NACIONAL \n(Incluye las pérdidas en transmisión)
# 92395 2021-04-08  ...                                            3769.00
# 92396 2021-04-08  ...                                            3645.15
# 92397 2021-04-08  ...                                            3575.04
# 92398 2021-04-08  ...                                            3463.42
# 92399 2021-04-08  ...                                            3346.59
#
# [5 rows x 6 columns]

# %%
df.rename(columns={'Día': 'Dia', 'PRODUCCIÓN  \n(Incluye las importaciones)': 'Produccion','DEMANDA NACIONAL \n(Incluye las pérdidas en transmisión)': 'Demanda' }, inplace=True)

# %%
df['day'] = df['Fecha'].dt.day
df['month'] = df['Fecha'].dt.month
df['year'] = df['Fecha'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92400 entries, 0 to 92399
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Fecha       92400 non-null  datetime64[ns]
#  1   Dia         92400 non-null  object
#  2   Hora        92400 non-null  object
#  3   FechaHora   92400 non-null  datetime64[ns]
#  4   Produccion  92400 non-null  float64
#  5   Demanda     92400 non-null  float64
#  6   day         92400 non-null  int64
#  7   month       92400 non-null  int64
#  8   year        92400 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(2)
# memory usage: 6.3+ MB

# %%
df.head()
# Out:
#        Fecha      Dia      Hora           FechaHora  ...  Demanda  day  month  year
# 0 2016-01-01  viernes  00:00:00 2016-01-01 00:00:00  ...  2396.90    1      1  2016
# 1 2016-01-01  viernes  00:30:00 2016-01-01 00:30:00  ...  2396.13    1      1  2016
# 2 2016-01-01  viernes  01:00:00 2016-01-01 01:00:00  ...  2358.84    1      1  2016
# 3 2016-01-01  viernes  01:30:00 2016-01-01 01:30:00  ...  2307.70    1      1  2016
# 4 2016-01-01  viernes  02:00:00 2016-01-01 02:00:00  ...  2231.39    1      1  2016
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#            Fecha     Dia      Hora  ... day  month  year
# 92395 2021-04-08  jueves  21:30:00  ...   8      4  2021
# 92396 2021-04-08  jueves  22:00:00  ...   8      4  2021
# 92397 2021-04-08  jueves  22:30:00  ...   8      4  2021
# 92398 2021-04-08  jueves  23:00:00  ...   8      4  2021
# 92399 2021-04-08  jueves  23:30:00  ...   8      4  2021
#
# [5 rows x 9 columns]

# %%
df.to_csv('DemandaNacional.csv', sep=',')

# %%
df_dia2018=df[(df['Fecha'] >= '2018-04-2') & (df['Fecha'] <= '2018-04-8')]
df_dia2018.reset_index(inplace=True)
df_dia2018
# Out:
#      index      Fecha      Dia      Hora  ...  Demanda  day  month  year
# 0    39456 2018-04-02    lunes  00:00:00  ...  2445.59    2      4  2018
# 1    39457 2018-04-02    lunes  00:30:00  ...  2370.05    2      4  2018
# 2    39458 2018-04-02    lunes  01:00:00  ...  2266.99    2      4  2018
# 3    39459 2018-04-02    lunes  01:30:00  ...  2231.82    2      4  2018
# 4    39460 2018-04-02    lunes  02:00:00  ...  2206.96    2      4  2018
# ..     ...        ...      ...       ...  ...      ...  ...    ...   ...
# 331  39787 2018-04-08  domingo  21:30:00  ...  3121.56    8      4  2018
# 332  39788 2018-04-08  domingo  22:00:00  ...  3005.57    8      4  2018
# 333  39789 2018-04-08  domingo  22:30:00  ...  2838.31    8      4  2018
# 334  39790 2018-04-08  domingo  23:00:00  ...  2733.62    8      4  2018
# 335  39791 2018-04-08  domingo  23:30:00  ...  2607.42    8      4  2018
#
# [336 rows x 10 columns]

# %%
df_dia2019=df[(df['Fecha'] >= '2019-04-1') & (df['Fecha'] <= '2019-04-7')]
df_dia2019.reset_index( inplace=True)
df_dia2019
# Out:
#      index      Fecha      Dia      Hora  ...  Demanda  day  month  year
# 0    56928 2019-04-01    lunes  00:00:00  ...  2647.30    1      4  2019
# 1    56929 2019-04-01    lunes  00:30:00  ...  2567.72    1      4  2019
# 2    56930 2019-04-01    lunes  01:00:00  ...  2482.83    1      4  2019
# 3    56931 2019-04-01    lunes  01:30:00  ...  2454.80    1      4  2019
# 4    56932 2019-04-01    lunes  02:00:00  ...  2413.78    1      4  2019
# ..     ...        ...      ...       ...  ...      ...  ...    ...   ...
# 331  57259 2019-04-07  domingo  21:30:00  ...  3234.34    7      4  2019
# 332  57260 2019-04-07  domingo  22:00:00  ...  3121.24    7      4  2019
# 333  57261 2019-04-07  domingo  22:30:00  ...  2970.70    7      4  2019
# 334  57262 2019-04-07  domingo  23:00:00  ...  2881.64    7      4  2019
# 335  57263 2019-04-07  domingo  23:30:00  ...  2737.92    7      4  2019
#
# [336 rows x 10 columns]

# %%
df_dia2020=df[(df['Fecha'] >= '2020-04-6') & (df['Fecha'] <= '2020-04-12')]
df_dia2020.reset_index( inplace=True)
df_dia2020
# Out:
#      index      Fecha      Dia      Hora  ...  Demanda  day  month  year
# 0    74736 2020-04-06    lunes  00:00:00  ...  2530.65    6      4  2020
# 1    74737 2020-04-06    lunes  00:30:00  ...  2430.49    6      4  2020
# 2    74738 2020-04-06    lunes  01:00:00  ...  2367.15    6      4  2020
# 3    74739 2020-04-06    lunes  01:30:00  ...  2317.03    6      4  2020
# 4    74740 2020-04-06    lunes  02:00:00  ...  2264.39    6      4  2020
# ..     ...        ...      ...       ...  ...      ...  ...    ...   ...
# 331  75067 2020-04-12  domingo  21:30:00  ...  2868.39   12      4  2020
# 332  75068 2020-04-12  domingo  22:00:00  ...  2786.01   12      4  2020
# 333  75069 2020-04-12  domingo  22:30:00  ...  2692.95   12      4  2020
# 334  75070 2020-04-12  domingo  23:00:00  ...  2604.06   12      4  2020
# 335  75071 2020-04-12  domingo  23:30:00  ...  2496.21   12      4  2020
#
# [336 rows x 10 columns]

# %%
df_comparacion = df_dia2018[['Dia']].copy()
df_comparacion['Produccion2018'] = df_dia2018['Produccion']
df_comparacion['Demanda2018'] = df_dia2018['Demanda']
df_comparacion['Produccion2019'] = df_dia2019['Produccion']
df_comparacion['Demanda2019'] = df_dia2019['Demanda']
df_comparacion['Produccion2020'] = df_dia2020['Produccion']
df_comparacion['Demanda2020'] = df_dia2020['Demanda']

df_comparacion['Hora'] = pd.to_datetime(df_dia2018['Hora'],format= '%H:%M:%S' ).dt.time
df_comparacion
# Out:
#          Dia  Produccion2018  ...  Demanda2020      Hora
# 0      lunes         2445.59  ...      2530.65  00:00:00
# 1      lunes         2370.05  ...      2430.49  00:30:00
# 2      lunes         2266.99  ...      2367.15  01:00:00
# 3      lunes         2231.82  ...      2317.03  01:30:00
# 4      lunes         2207.57  ...      2264.39  02:00:00
# ..       ...             ...  ...          ...       ...
# 331  domingo         3267.88  ...      2868.39  21:30:00
# 332  domingo         3153.78  ...      2786.01  22:00:00
# 333  domingo         2991.00  ...      2692.95  22:30:00
# 334  domingo         2751.58  ...      2604.06  23:00:00
# 335  domingo         2610.43  ...      2496.21  23:30:00
#
# [336 rows x 8 columns]

# %%
df_comparacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dia             336 non-null    object
#  1   Produccion2018  336 non-null    float64
#  2   Demanda2018     336 non-null    float64
#  3   Produccion2019  336 non-null    float64
#  4   Demanda2019     336 non-null    float64
#  5   Produccion2020  336 non-null    float64
#  6   Demanda2020     336 non-null    float64
#  7   Hora            336 non-null    object
# dtypes: float64(6), object(2)
# memory usage: 21.1+ KB

# %%
df_comparacion.to_csv('ComparacionSemana.csv', sep=',')

# %%
df_anio2016=df[(df['year'] == 2016)]
df_anio2016.reset_index(inplace=True)
df_anio2017=df[(df['year'] == 2017)]
df_anio2017.reset_index(inplace=True)
df_anio2018=df[(df['year'] == 2018)]
df_anio2018.reset_index(inplace=True)
df_anio2019=df[(df['year'] == 2019)]
df_anio2019.reset_index(inplace=True)
df_anio2020=df[(df['year'] == 2020)]
df_anio2020.reset_index(inplace=True)
df_anio2021=df[(df['year'] == 2021)]
df_anio2021.reset_index(inplace=True)

df_comparacion_anio = df_anio2016[['Fecha','day','month', 'year']].copy()
df_comparacion_anio['Produccion2016'] = df_anio2016['Produccion']
df_comparacion_anio['Demanda2016'] = df_anio2016['Demanda']
df_comparacion_anio['Produccion2017'] = df_anio2017['Produccion']
df_comparacion_anio['Demanda2017'] = df_anio2017['Demanda']
df_comparacion_anio['Produccion2018'] = df_anio2018['Produccion']
df_comparacion_anio['Demanda2018'] = df_anio2018['Demanda']
df_comparacion_anio['Produccion2019'] = df_anio2019['Produccion']
df_comparacion_anio['Demanda2019'] = df_anio2019['Demanda']
df_comparacion_anio['Produccion2020'] = df_anio2020['Produccion']
df_comparacion_anio['Demanda2020'] = df_anio2020['Demanda']
df_comparacion_anio['Produccion2021'] = df_anio2021['Produccion']
df_comparacion_anio['Demanda2021'] = df_anio2021['Demanda']

df_comparacion_anio['Hora'] = pd.to_datetime(df_anio2018['Hora'],format= '%H:%M:%S' ).dt.time
df_comparacion_anio.fillna(0, inplace=True)
df_comparacion_anio
#df_comparacion_anio.to_csv('ComparacionAnios.csv', sep=',')
# Out:
#            Fecha  day  month  ...  Produccion2021  Demanda2021      Hora
# 0     2016-01-01    1      1  ...         2705.50      2705.50  00:00:00
# 1     2016-01-01    1      1  ...         2700.24      2688.22  00:30:00
# 2     2016-01-01    1      1  ...         2646.11      2641.08  01:00:00
# 3     2016-01-01    1      1  ...         2588.47      2585.46  01:30:00
# 4     2016-01-01    1      1  ...         2532.26      2532.26  02:00:00
# ...          ...  ...    ...  ...             ...          ...       ...
# 17563 2016-12-31   31     12  ...            0.00         0.00         0
# 17564 2016-12-31   31     12  ...            0.00         0.00         0
# 17565 2016-12-31   31     12  ...            0.00         0.00         0
# 17566 2016-12-31   31     12  ...            0.00         0.00         0
# 17567 2016-12-31   31     12  ...            0.00         0.00         0
#
# [17568 rows x 17 columns]

# %%
df_semana['Produccion'].plot(kind='line')
plt.title('Consumo semanal')
plt.ylabel('[KW]')
plt.xlabel('Horas')
plt.figure(figsize=(20,5))
plt.show()

# %%
df_semana.plot(kind='area', 
             alpha= 0.8, # 0-1, default value a= 0.5
             stacked=False,
             figsize=(20, 10),
            )

plt.title('Análisis de consumo Eléctrico  diario a nivel Nacional')
plt.ylabel('Consumo KW')
plt.xlabel('Fecha')

plt.show()
